# %% [markdown]
# # Overfitting demo
#
# ## Create a dataset based on a true sinusoidal relationship
# Let's look at a synthetic dataset consisting of 30 points drawn from the sinusoid $y = \sin(4x)$:

# %%
# import sys
# sys.path.append('C:\Anaconda2\envs\dato-env\Lib\site-packages')
import turicreate
import math
import random
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Create random values for x in interval [0,1)

# %%
random.seed(98103)
n = 30
x = turicreate.SArray([random.random() for i in range(n)]).sort()

# %% [markdown]
# Compute y

# %%
y = x.apply(lambda x: math.sin(4*x))

# %% [markdown]
# Add random Gaussian noise to y

# %%
random.seed(1)
e = turicreate.SArray([random.gauss(0,1.0/3.0) for i in range(n)])
y = y + e

# %% [markdown]
# ### Put data into an SFrame to manipulate later

# %%
data = turicreate.SFrame({'X1':x,'Y':y})
data
# Out:
# Columns:
# 	X1	float
# 	Y	float
#
# Rows: 30
#
# Data:
# +---------------------+---------------------+
# |          X1         |          Y          |
# +---------------------+---------------------+
# | 0.03957894495006575 |  0.5870501910256387 |
# | 0.04156809967912256 |  0.6486558513722105 |
# |  0.0724319480800758 | 0.30780330948476986 |
# |  0.1502890446221763 | 0.31074844741664676 |
# | 0.16133414450223427 | 0.23740962549610656 |
# | 0.19195631279497838 |  0.7050171572238372 |
# | 0.23283391714465285 |  0.4617166769923188 |
# | 0.25990098016580054 | 0.38326050785082555 |
# |  0.3801458148686865 |  1.065176914291498  |
# |  0.432444723507992  |  1.031847069489963  |
# +---------------------+---------------------+
# [30 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# ### Create a function to plot the data, since we'll do it many times

# %%
def plot_data(data):    
    plt.plot(data['X1'],data['Y'],'r.')
    plt.xlabel('x')
    plt.ylabel('y')

plot_data(data)

# %% [markdown]
# ## Define some useful polynomial regression functions

# %% [markdown]
# Define a function to create our features for a polynomial regression model of any degree:

# %%
def polynomial_features(data, deg):
    data_copy=data.copy()
    for i in range(1,deg):
        data_copy['X'+str(i+1)]=data_copy['X'+str(i)]*data_copy['X1']
    return data_copy

# %% [markdown]
# Define a function to fit a polynomial linear regression model of degree "deg" to the data in "data":

# %%
def polynomial_regression(data, deg):
    model = turicreate.linear_regression.create(polynomial_features(data,deg), 
                                              target='Y', l2_penalty=0.,l1_penalty=0.,
                                              validation_set=None,verbose=False)
    return model

# %% [markdown]
# Define function to plot data and predictions made, since we are going to use it many times.

# %%
def plot_poly_predictions(data, model):
    plot_data(data)

    # Get the degree of the polynomial
    deg = len(model.coefficients['value'])-1
    
    # Create 200 points in the x axis and compute the predicted value for each point
    x_pred = turicreate.SFrame({'X1':[i/200.0 for i in range(200)]})
    y_pred = model.predict(polynomial_features(x_pred,deg))
    
    # plot predictions
    plt.plot(x_pred['X1'], y_pred, 'g-', label='degree ' + str(deg) + ' fit')
    plt.legend(loc='upper left')
    plt.axis([0,1,-1.5,2])

# %% [markdown]
# Create a function that prints the polynomial coefficients in a pretty way :)

# %%
def print_coefficients(model):    
    # Get the degree of the polynomial
    deg = len(model.coefficients['value'])-1

    # Get learned parameters as a list
    w = list(model.coefficients['value'])

    # Numpy has a nifty function to print out polynomials in a pretty way
    # (We'll use it, but it needs the parameters in the reverse order)
    print ('Learned polynomial for degree ' + str(deg) + ':')
    w.reverse()
    print (numpy.poly1d(w))

# %% [markdown]
# ## Fit a degree-2 polynomial

# %% [markdown]
# Fit our degree-2 polynomial to the data generated above:

# %%
model = polynomial_regression(data, deg=2)

# %% [markdown]
# Inspect learned parameters

# %%
print_coefficients(model)
# Out:
# Learned polynomial for degree 16:
#         16          15          14          13          12         11
# -0.301 x  - 0.2802 x  - 0.2604 x  - 0.2413 x  - 0.2229 x  - 0.205 x
#            10          9          8          7          6           5
#  - 0.1874 x  - 0.1699 x - 0.1524 x - 0.1344 x - 0.1156 x - 0.09534 x
#             4           3           2
#  - 0.07304 x - 0.04842 x - 0.02284 x - 0.002257 x + 0.6416

# %% [markdown]
# Form and plot our predictions along a grid of x values:

# %%
plot_poly_predictions(data,model)

# %% [markdown]
# ## Fit a degree-4 polynomial

# %%
model = polynomial_regression(data, deg=4)
print_coefficients(model)
plot_poly_predictions(data,model)
# Out:
# Learned polynomial for degree 4:
#        4         3         2
# 23.87 x - 53.82 x + 35.23 x - 6.828 x + 0.7755

# %% [markdown]
# ## Fit a degree-16 polynomial

# %%
model = polynomial_regression(data, deg=16)
print_coefficients(model)
# Out:
# Learned polynomial for degree 16:
#            16             15             14             13
# 2.643e+06 x  - 1.036e+07 x  + 1.151e+07 x  + 6.987e+06 x
#               12             11             10             9
#  - 2.659e+07 x  + 2.148e+07 x  - 5.181e+06 x  + 3.959e+06 x
#               8             7             6             5             4
#  - 1.316e+07 x + 1.537e+07 x - 9.448e+06 x + 3.496e+06 x - 8.048e+05 x
#              3        2
#  + 1.13e+05 x - 9045 x + 357.4 x - 4.701

# %% [markdown]
# ### Woah!!!!  Those coefficients are *crazy*!  On the order of 10^6.

# %%
plot_poly_predictions(data,model)

# %% [markdown]
# ### Above: Fit looks pretty wild, too.  Here's a clear example of how overfitting is associated with very large magnitude estimated coefficients.

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
#  #

# %% [markdown]
#  #

# %% [markdown]
# # Ridge Regression

# %% [markdown]
# Ridge regression aims to avoid overfitting by adding a cost to the RSS term of standard least squares that depends on the 2-norm of the coefficients $\|w\|$.  The result is penalizing fits with large coefficients.  The strength of this penalty, and thus the fit vs. model complexity balance, is controled by a parameter lambda (here called "L2_penalty").

# %% [markdown]
# Define our function to solve the ridge objective for a polynomial regression model of any degree:

# %%
def polynomial_ridge_regression(data, deg, l2_penalty):
    model = turicreate.linear_regression.create(polynomial_features(data,deg), 
                                              target='Y', l2_penalty=l2_penalty,
                                              validation_set=None,verbose=False)
    return model

# %% [markdown]
# ## Perform a ridge fit of a degree-16 polynomial using a *very* small penalty strength

# %%
model = polynomial_ridge_regression(data, deg=16, l2_penalty=1e-25)
print_coefficients(model)
# Out:
# Learned polynomial for degree 16:
#            16             15             14             13
# 2.643e+06 x  - 1.036e+07 x  + 1.151e+07 x  + 6.987e+06 x
#               12             11             10             9
#  - 2.659e+07 x  + 2.148e+07 x  - 5.181e+06 x  + 3.959e+06 x
#               8             7             6             5             4
#  - 1.316e+07 x + 1.537e+07 x - 9.448e+06 x + 3.496e+06 x - 8.048e+05 x
#              3        2
#  + 1.13e+05 x - 9045 x + 357.4 x - 4.701

# %%
plot_poly_predictions(data,model)

# %% [markdown]
# ## Perform a ridge fit of a degree-16 polynomial using a very large penalty strength

# %%
model = polynomial_ridge_regression(data, deg=16, l2_penalty=100)
print_coefficients(model)
# Out:
# Learned polynomial for degree 16:
#         16          15          14          13          12         11
# -0.301 x  - 0.2802 x  - 0.2604 x  - 0.2413 x  - 0.2229 x  - 0.205 x
#            10          9          8          7          6           5
#  - 0.1874 x  - 0.1699 x - 0.1524 x - 0.1344 x - 0.1156 x - 0.09534 x
#             4           3           2
#  - 0.07304 x - 0.04842 x - 0.02284 x - 0.002257 x + 0.6416

# %%
plot_poly_predictions(data,model)

# %% [markdown]
# ## Let's look at fits for a sequence of increasing lambda values

# %%
for l2_penalty in [1e-25, 1e-10, 1e-6, 1e-3, 1e2]:
    model = polynomial_ridge_regression(data, deg=16, l2_penalty=l2_penalty)
    print ('lambda = %.2e' % l2_penalty)
    print_coefficients(model)
    print ('\n')
    plt.figure()
    plot_poly_predictions(data,model)
    plt.title('Ridge, lambda = %.2e' % l2_penalty)
# Out:
# lambda = 1.00e-25
# Learned polynomial for degree 16:
#            16             15             14             13
# 2.643e+06 x  - 1.036e+07 x  + 1.151e+07 x  + 6.987e+06 x
#               12             11             10             9
#  - 2.659e+07 x  + 2.148e+07 x  - 5.181e+06 x  + 3.959e+06 x
#               8             7             6             5             4
#  - 1.316e+07 x + 1.537e+07 x - 9.448e+06 x + 3.496e+06 x - 8.048e+05 x
#              3        2
#  + 1.13e+05 x - 9045 x + 357.4 x - 4.701
#
#
# lambda = 1.00e-10
# Learned polynomial for degree 16:
#            16            15             14             13
# 4.974e+04 x  - 7.82e+04 x  - 2.266e+04 x  + 3.949e+04 x
#               12        11             10             9             8
#  + 4.366e+04 x  + 3076 x  - 3.332e+04 x  - 2.786e+04 x + 1.032e+04 x
#               7        6             5             4        3         2
#  + 2.962e+04 x - 1439 x - 2.597e+04 x + 1.839e+04 x - 5596 x + 866.2 x - 65.19 x + 2.159
#
#
# lambda = 1.00e-06
# Learned polynomial for degree 16:
#        16         15         14        13         12         11
# 329.1 x  - 356.4 x  - 264.2 x  + 33.8 x  + 224.7 x  + 210.8 x
#           10         9       8         7         6         5         4
#  + 49.62 x  - 122.4 x - 178 x - 79.13 x + 84.89 x + 144.9 x + 5.123 x
#           3         2
#  - 156.9 x + 88.21 x - 14.82 x + 1.059
#
#
# lambda = 1.00e-03
# Learned polynomial for degree 16:
#        16         15         14         13         12          11
# 6.364 x  - 1.596 x  - 4.807 x  - 4.778 x  - 2.776 x  + 0.1238 x
#           10         9         8         7          6         5
#  + 2.977 x  + 4.926 x + 5.203 x + 3.248 x - 0.9291 x - 6.011 x
#           4         3         2
#  - 8.395 x - 2.655 x + 9.861 x - 2.225 x + 0.5636
#
#
# lambda = 1.00e+02
# Learned polynomial for degree 16:
#         16          15          14          13          12         11
# -0.301 x  - 0.2802 x  - 0.2604 x  - 0.2413 x  - 0.2229 x  - 0.205 x
#            10          9          8          7          6           5
#  - 0.1874 x  - 0.1699 x - 0.1524 x - 0.1344 x - 0.1156 x - 0.09534 x
#             4           3           2
#  - 0.07304 x - 0.04842 x - 0.02284 x - 0.002257 x + 0.6416

# %% [markdown]
# ## Perform a ridge fit of a degree-16 polynomial using a "good" penalty strength

# %% [markdown]
# We will learn about cross validation later in this course as a way to select a good value of the tuning parameter (penalty strength) lambda.  Here, we consider "leave one out" (LOO) cross validation, which one can show approximates average mean square error (MSE).  As a result, choosing lambda to minimize the LOO error is equivalent to choosing lambda to minimize an approximation to average MSE.

# %%
pip install -e git+https://github.com/Kagandi/turicreate-cross-validation.git#egg=turicreate_cross_validation
# Out:
# Obtaining turicreate_cross_validation from git+https://github.com/Kagandi/turicreate-cross-validation.git#egg=turicreate_cross_validation
#   Updating ./src/turicreate-cross-validation clone
# Requirement already satisfied: turicreate in /home/madhu/anaconda3/lib/python3.7/site-packages (from turicreate_cross_validation) (6.3)
# Requirement already satisfied: numpy in /home/madhu/anaconda3/lib/python3.7/site-packages (from turicreate_cross_validation) (1.18.1)
# Requirement already satisfied: prettytable==0.7.2 in /home/madhu/anaconda3/lib/python3.7/site-packages (from turicreate->turicreate_cross_validation) (0.7.2)
# Requirement already satisfied: pillow>=5.2.0 in /home/madhu/anaconda3/lib/python3.7/site-packages (from turicreate->turicreate_cross_validation) (7.0.0)
# Requirement already satisfied: tensorflow<=2.0.1,>=2.0.0 in /home/madhu/anaconda3/lib/python3.7/site-packages (from turicreate->turicreate_cross_validation) (2.0.1)
# Requirement already satisfied: coremltools==3.3 in /home/madhu/anaconda3/lib/python3.7/site-packages (from turicreate->turicreate_cross_validation) (3.3)
# Requirement already satisfied: pandas>=0.23.2 in /home/madhu/anaconda3/lib/python3.7/site-packages (from turicreate->turicreate_cross_validation) (1.0.1)
# Requirement already satisfied: requests>=2.9.1 in /home/madhu/anaconda3/lib/python3.7/site-packages (from turicreate->turicreate_cross_validation) (2.22.0)
# Requirement already satisfied: decorator>=4.0.9 in /home/madhu/anaconda3/lib/python3.7/site-packages (from turicreate->turicreate_cross_validation) (4.4.1)
# Requirement already satisfied: scipy>=1.1.0 in /home/madhu/anaconda3/lib/python3.7/site-packages (from turicreate->turicreate_cross_validation) (1.4.1)
# Requirement already satisfied: resampy==0.2.1 in /home/madhu/anaconda3/lib/python3.7/site-packages (from turicreate->turicreate_cross_validation) (0.2.1)
# Requirement already satisfied: six>=1.10.0 in /home/madhu/anaconda3/lib/python3.7/site-packages (from turicreate->turicreate_cross_validation) (1.14.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (1.1.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (0.34.2)
# Requirement already satisfied: grpcio>=1.8.6 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (1.27.2)
# Requirement already satisfied: keras-applications>=1.0.8 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (0.8.1)
# Requirement already satisfied: absl-py>=0.7.0 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (0.9.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (0.2.0)
# Requirement already satisfied: protobuf>=3.6.1 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (3.12.3)
# Requirement already satisfied: tensorboard<2.1.0,>=2.0.0 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (2.0.2)
# Requirement already satisfied: tensorflow-estimator<2.1.0,>=2.0.0 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (2.0.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (3.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (1.1.0)
# Requirement already satisfied: gast==0.2.2 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (0.2.2)
# Requirement already satisfied: wrapt>=1.11.1 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (1.11.2)
# Requirement already satisfied: pytz>=2017.2 in /home/madhu/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.2->turicreate->turicreate_cross_validation) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/madhu/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.2->turicreate->turicreate_cross_validation) (2.8.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/madhu/anaconda3/lib/python3.7/site-packages (from requests>=2.9.1->turicreate->turicreate_cross_validation) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/madhu/anaconda3/lib/python3.7/site-packages (from requests>=2.9.1->turicreate->turicreate_cross_validation) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/madhu/anaconda3/lib/python3.7/site-packages (from requests>=2.9.1->turicreate->turicreate_cross_validation) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/madhu/anaconda3/lib/python3.7/site-packages (from requests>=2.9.1->turicreate->turicreate_cross_validation) (1.25.8)
# Requirement already satisfied: numba>=0.32 in /home/madhu/anaconda3/lib/python3.7/site-packages (from resampy==0.2.1->turicreate->turicreate_cross_validation) (0.48.0)
# Requirement already satisfied: h5py in /home/madhu/anaconda3/lib/python3.7/site-packages (from keras-applications>=1.0.8->tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (2.10.0)
# Requirement already satisfied: setuptools in /home/madhu/anaconda3/lib/python3.7/site-packages (from protobuf>=3.6.1->tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (45.2.0.post20200210)
# Requirement already satisfied: markdown>=2.6.8 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (3.1.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (1.17.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (0.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/madhu/anaconda3/lib/python3.7/site-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (1.0.0)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /home/madhu/anaconda3/lib/python3.7/site-packages (from numba>=0.32->resampy==0.2.1->turicreate->turicreate_cross_validation) (0.31.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/madhu/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/madhu/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (4.1.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /home/madhu/anaconda3/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (4.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/madhu/anaconda3/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/madhu/anaconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/madhu/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow<=2.0.1,>=2.0.0->turicreate->turicreate_cross_validation) (3.1.0)
# Installing collected packages: turicreate-cross-validation
#   Attempting uninstall: turicreate-cross-validation
#     Found existing installation: turicreate-cross-validation 0.1
#     Uninstalling turicreate-cross-validation-0.1:
#       Successfully uninstalled turicreate-cross-validation-0.1
#   Running setup.py develop for turicreate-cross-validation
# Successfully installed turicreate-cross-validation
# Note: you may need to restart the kernel to use updated packages.

# %%
# from turicreate.cross_validation import shuffle_sframe, StratifiedKFold, cross_val_score

# LOO cross validation -- return the average MSE
def loo(data, deg, l2_penalty_values):
    # Create polynomial features
    polynomial_features(data, deg)
    
    # Create as many folds for cross validatation as number of data points
    num_folds = len(data)
    folds = turicreate.toolkits.cross_validation.KFold(data,num_folds)
    
    # for each value of l2_penalty, fit a model for each fold and compute average MSE
    l2_penalty_mse = []
    min_mse = None
    best_l2_penalty = None
    for l2_penalty in l2_penalty_values:
        next_mse = 0.0
        for train_set, validation_set in folds:
            # train model
            model = turicreate.linear_regression.create(train_set,target='Y', 
                                                      l2_penalty=l2_penalty,
                                                      validation_set=None,verbose=False)
            
            # predict on validation set 
            y_test_predicted = model.predict(validation_set)
            # compute squared error
            next_mse += ((y_test_predicted-validation_set['Y'])**2).sum()
        
        # save squared error in list of MSE for each l2_penalty
        next_mse = next_mse/num_folds
        l2_penalty_mse.append(next_mse)
        if min_mse is None or next_mse < min_mse:
            min_mse = next_mse
            best_l2_penalty = l2_penalty
            
    return l2_penalty_mse,best_l2_penalty

# %% [markdown]
# Run LOO cross validation for "num" values of lambda, on a log scale

# %%
l2_penalty_values = numpy.logspace(-4, 10, num=10)
l2_penalty_mse,best_l2_penalty = loo(data, 16, l2_penalty_values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-a5fd4b92f787> in <module>
#       1 l2_penalty_values = numpy.logspace(-4, 10, num=10)
# ----> 2 l2_penalty_mse,best_l2_penalty = loo(data, 16, l2_penalty_values)
#
# <ipython-input-84-53805d7fdaec> in loo(data, deg, l2_penalty_values)
#       8     # Create as many folds for cross validatation as number of data points
#       9     num_folds = len(data)
# ---> 10     folds = turicreate.toolkits.cross_validation.KFold(data,num_folds)
#      11
#      12     # for each value of l2_penalty, fit a model for each fold and compute average MSE
#
# AttributeError: module 'turicreate.toolkits' has no attribute 'cross_validation'

# %% [markdown]
# Plot results of estimating LOO for each value of lambda

# %%
plt.plot(l2_penalty_values,l2_penalty_mse,'k-')
plt.xlabel('$\L2_penalty$')
plt.ylabel('LOO cross validation error')
plt.xscale('log')
plt.yscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-f1d822de47af> in <module>
# ----> 1 plt.plot(l2_penalty_values,l2_penalty_mse,'k-')
#       2 plt.xlabel('$\L2_penalty$')
#       3 plt.ylabel('LOO cross validation error')
#       4 plt.xscale('log')
#       5 plt.yscale('log')
#
# NameError: name 'l2_penalty_mse' is not defined

# %% [markdown]
# Find the value of lambda, $\lambda_{\mathrm{CV}}$, that minimizes the LOO cross validation error, and plot resulting fit

# %%
best_l2_penalty
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-27e308ab7c47> in <module>
# ----> 1 best_l2_penalty
#
# NameError: name 'best_l2_penalty' is not defined

# %%
model = polynomial_ridge_regression(data, deg=16, l2_penalty=best_l2_penalty)
print_coefficients(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-4af2c7d431f1> in <module>
# ----> 1 model = polynomial_ridge_regression(data, deg=16, l2_penalty=best_l2_penalty)
#       2 print_coefficients(model)
#
# NameError: name 'best_l2_penalty' is not defined

# %%
plot_poly_predictions(data,model)

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# # Lasso Regression

# %% [markdown]
# Lasso regression jointly shrinks coefficients to avoid overfitting, and implicitly performs feature selection by setting some coefficients exactly to 0 for sufficiently large penalty strength lambda (here called "L1_penalty").  In particular, lasso takes the RSS term of standard least squares and adds a 1-norm cost of the coefficients $\|w\|$.

# %% [markdown]
# Define our function to solve the lasso objective for a polynomial regression model of any degree:

# %%
def polynomial_lasso_regression(data, deg, l1_penalty):
    model = turicreate.linear_regression.create(polynomial_features(data,deg), 
                                              target='Y', l2_penalty=0.,
                                              l1_penalty=l1_penalty,
                                              validation_set=None, 
                                              solver='fista', verbose=False,
                                              max_iterations=3000, convergence_threshold=1e-10)
    return model

# %% [markdown]
# ## Explore the lasso solution as a function of a few different penalty strengths

# %% [markdown]
# We refer to lambda in the lasso case below as "l1_penalty"

# %%
for l1_penalty in [0.0001, 0.01, 0.1, 10]:
    model = polynomial_lasso_regression(data, deg=16, l1_penalty=l1_penalty)
    print ('l1_penalty = %e' % l1_penalty)
    print ('number of nonzeros = %d' % (model.coefficients['value']).nnz())
    print_coefficients(model)
    print ('\n')
    plt.figure()
    plot_poly_predictions(data,model)
    plt.title('LASSO, lambda = %.2e, # nonzeros = %d' % (l1_penalty, (model.coefficients['value']).nnz()))
# Out:
# l1_penalty = 1.000000e-04
# number of nonzeros = 17
# Learned polynomial for degree 16:
#        16        15         14         13         12         11
# 29.02 x  + 1.35 x  - 12.72 x  - 16.93 x  - 13.82 x  - 6.698 x
#           10         9         8         7         6         5
#  + 1.407 x  + 8.939 x + 12.88 x + 11.44 x + 3.759 x - 8.062 x
#           4         3         2
#  - 16.28 x - 7.682 x + 17.86 x - 4.384 x + 0.685
#
#
# l1_penalty = 1.000000e-02
# number of nonzeros = 14
# Learned polynomial for degree 16:
#         16             15           11          10         9          8
# -1.181 x  - 0.0004426 x  + 0.08673 x  + 0.7383 x  + 3.828 x + 0.4757 x
#           7            6          5         4             3         2
#  + 0.128 x + 0.003306 x - 0.6152 x - 10.11 x + 0.0003893 x + 6.686 x - 1.28 x + 0.5055
#
#
# l1_penalty = 1.000000e-01
# number of nonzeros = 5
# Learned polynomial for degree 16:
#       16         6         5
# 2.21 x  - 1.002 x - 2.962 x + 1.216 x + 0.3473
#
#
# l1_penalty = 1.000000e+01
# number of nonzeros = 2
# Learned polynomial for degree 16:
#         9
# -1.526 x + 0.5755

# %% [markdown]
# Above: We see that as lambda increases, we get sparser and sparser solutions.  However, even for our non-sparse case for lambda=0.0001, the fit of our high-order polynomial is not too wild.  This is because, like in ridge, coefficients included in the lasso solution are shrunk relative to those of the least squares (unregularized) solution.  This leads to better behavior even without sparsity.  Of course, as lambda goes to 0, the amount of this shrinkage decreases and the lasso solution approaches the (wild) least squares solution.
